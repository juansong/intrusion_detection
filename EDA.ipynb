# %% [markdown]
# # EDA

# %%
# Libraries
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import probplot
import matplotlib.pyplot as plt
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
df = pd.read_csv('df_preproc_02.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017939 entries, 0 to 1017938
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Bwd Packet Length Std   1017939 non-null  float64
#  1   PSH Flag Count          1017939 non-null  int64
#  2   min_seg_size_forward    1017939 non-null  int64
#  3   Min Packet Length       1017939 non-null  int64
#  4   ACK Flag Count          1017939 non-null  int64
#  5   Bwd Packet Length Min   1017939 non-null  int64
#  6   Fwd IAT Std             1017939 non-null  float64
#  7   Init_Win_bytes_forward  1017939 non-null  int64
#  8   Flow IAT Max            1017939 non-null  int64
#  9   Bwd Packets/s           1017939 non-null  float64
#  10  URG Flag Count          1017939 non-null  int64
#  11  Bwd IAT Total           1017939 non-null  int64
#  12  Label                   1017939 non-null  object
# dtypes: float64(3), int64(9), object(1)
# memory usage: 101.0+ MB

# %%
# define X and y
import pylab
y = df['Label']
X = df.drop(['Label'], axis = 1)
cols = X.columns
# plot qqplot for indep vars (X)
plt.style.use('dark_background')
for c in cols:
    probplot(X[c],dist='norm',plot=pylab)
    pylab.show()

# %%
# plot X (independent) variables (continuous / binary)
sns.set(style='ticks',context='talk')
#plt.style.use('dark_background')
for c in cols:
    if (len(X[c].unique()) <=2):
        sns.histplot(x=X[c],y=y)
        plt.show()
    else:
        sns.boxplot(x=X[c],y=y)
        plt.show()

# %%
# plot heatmap
fig = plt.figure(figsize=(40,40))
sns.set(style='ticks',context='talk')
sns.heatmap(X.corr(), annot=True)
plt.yticks(rotation=0)
plt.show()
